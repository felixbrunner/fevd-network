# %% [markdown]
# # 04 - Regression Analysis

# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

import statsmodels.api as sm
import statsmodels.formula.api as smf
import linearmodels as lm

import datetime as dt

import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:49: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   data_klasses = (pandas.Series, pandas.DataFrame, pandas.Panel)

# %%
import sys
sys.path.append('../')
sys.path.append('../../kungfu/')
import kungfu as kf
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %% [markdown]
# ## Settings

# %%
pd.set_option('display.float_format', lambda x: '%.4f' % x) #sets decimals to be displayed

# %%
# %matplotlib inline

# %%
#sns.set()
#sns.set(rc={'figure.figsize': (17, 6)})

# %%
#plt.style.use('fivethirtyeight')
plt.style.use('seaborn')
plt.rcParams['figure.figsize'] = [17, 8]
#plt.rcParams['figure.dpi'] = 80

# %% [markdown]
# ## Load & prepare data
# #### Previously saved

# %%
df_crsp_desc = pd.read_pickle('../data/raw/df_crsp_desc.pkl')

# %%
df_ff_raw = pd.read_pickle('../data/raw/df_ff_raw.pkl')
df_ff_raw['date'] = pd.to_datetime(df_ff_raw['date'], yearfirst=True)
df_ff_raw = df_ff_raw.set_index('date')

# %%
df_estimates = pd.read_pickle('../data/processed/df_estimates.pkl')
df_analysis = pd.read_pickle('../data/processed/df_analysis.pkl')

# %%
df_indices = pd.read_pickle('../data/processed/df_indices.pkl')

# %% [markdown]
# ## Merge data & Explore

# %%
df_merged = kf.FinancialDataFrame(df_estimates.merge(df_analysis, how='outer', left_index=True, right_index=True, suffixes=('_est','_ana')))

# %%
df_merged.describe()
# Out:
#              in       out  capm_alpha_est  capm_mktrf_est  ff3f_alpha_est  \
# count 1900.0000 1900.0000       1900.0000       1900.0000       1900.0000
# mean     0.0050    0.0050          0.0003          0.9737          0.0003
# std      0.0068    0.0053          0.0009          0.4127          0.0009
# min      0.0000    0.0001         -0.0047         -0.1588         -0.0033
# 25%      0.0012    0.0014         -0.0002          0.7197         -0.0002
# 50%      0.0027    0.0029          0.0003          0.9458          0.0003
# 75%      0.0058    0.0065          0.0008          1.1952          0.0007
# max      0.0560    0.0253          0.0074          3.0914          0.0097
#
#        ff3f_mktrf_est  ff3f_smb_est  ff3f_hml_est  c4f_alpha_est  \
# count       1900.0000     1900.0000     1900.0000      1900.0000
# mean           1.0048       -0.1737       -0.0036         0.0003
# std            0.3358        0.3094        0.7337         0.0009
# min           -0.0147       -2.4796       -2.6741        -0.0034
# 25%            0.7749       -0.3604       -0.3927        -0.0002
# 50%            0.9955       -0.1836       -0.0626         0.0003
# 75%            1.2156       -0.0055        0.3468         0.0007
# max            2.3580        1.2087        4.5024         0.0096
#
#        c4f_mktrf_est  ...  ff3f_hml_ana  c4f_alpha_ana  c4f_mktrf_ana  \
# count      1900.0000  ...     1896.0000      1896.0000      1896.0000
# mean          1.0076  ...       -0.0028         0.0001         1.0013
# std           0.2953  ...        0.7829         0.0011         0.3718
# min           0.0513  ...      -10.7869        -0.0152        -7.1080
# 25%           0.8073  ...       -0.3816        -0.0003         0.8027
# 50%           1.0033  ...       -0.0704         0.0001         0.9988
# 75%           1.1941  ...        0.3249         0.0006         1.1859
# max           2.3399  ...        4.4606         0.0270         5.0156
#
#        c4f_smb_ana  c4f_hml_ana  c4f_umd_ana  ret1M_ana  ret3M_ana  \
# count    1896.0000    1896.0000    1896.0000  1896.0000  1896.0000
# mean       -0.1578       0.0045      -0.0609     0.0012     0.0110
# std         0.3625       0.7213       0.4651     0.0916     0.1338
# min        -6.2110     -12.5025      -2.8380    -0.5327    -0.6989
# 25%        -0.3276      -0.3545      -0.2909    -0.0500    -0.0588
# 50%        -0.1698      -0.0631      -0.0272    -0.0009     0.0133
# 75%        -0.0004       0.3077       0.1963     0.0536     0.0885
# max         6.7001       4.7785       2.3497     0.8183     0.8183
#
#        ret12M_ana   ret_ana
# count   1896.0000 1896.0000
# mean       0.0834    0.0834
# std        0.2875    0.2875
# min       -1.0000   -1.0000
# 25%       -0.0701   -0.0701
# 50%        0.0893    0.0893
# 75%        0.2428    0.2428
# max        1.6232    1.6232
#
# [8 rows x 32 columns]

# %%
sns.pairplot(df_merged.loc[:,['in','out','capm_mktrf_est','capm_mktrf_ana','c4f_mktrf_ana','c4f_smb_ana','c4f_hml_ana','c4f_umd_ana','ret1M_ana','ret3M_ana','ret12M_ana']])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sns.heatmap(df_merged.corr().round(2), annot=True, linewidths=.5)
plt.show()

# %% [markdown]
# ## Regressions

# %%
exogs = ['in',
         'capm_mktrf_est',
         ['in','out','capm_mktrf_est']]
effects = [[],
           ['time'],
           ['entity'],
           ['time', 'entity']]

add_outputs = ['Time FE', 'Entity FE', 'N', 'R-squared', 'R-squared (inclusive)']

var_order = ['const','in','out','capm_mktrf_est']

# %%
table_panel_regressions = kf.RegressionTable()
endog = 'ret1M_ana'

for exog in exogs:
    for fixed_effects in effects:
        table_panel_regressions = table_panel_regressions\
            .join_regression(df_merged.fit_panel_regression\
            (endog=endog, exog=exog, fixed_effects=fixed_effects, lag=1),\
            add_outputs=add_outputs)
table_panel_regressions\
    .change_variable_order(var_order)\
    .change_descriptive_order(add_outputs)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\linearmodels\utility.py:549: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)
#                                     (1)       (2)        (3)       (4)  \
# const                 coeff     -0.0087
#                       t-stat  (-0.8447)
# in                    coeff   1.2367***    0.5208  1.2947***  0.4247**
#                       t-stat   (3.1840)  (1.4068)   (3.1640)  (2.1046)
# out                   coeff
#                       t-stat
# capm_mktrf_est        coeff
#                       t-stat
# Time FE                           False      True      False      True
# Entity FE                         False     False       True      True
# N                                  1675      1675       1675      1675
# R-squared                        0.0094    0.0021     0.0096    0.0013
# R-squared (inclusive)            0.0094    0.2412     0.1330    0.3496
#
#                                     (5)       (6)       (7)       (8)  \
# const                 coeff    -0.0145*
#                       t-stat  (-1.8896)
# in                    coeff
#                       t-stat
# out                   coeff
#                       t-stat
# capm_mktrf_est        coeff      0.0122    0.0098    0.0052    0.0036
#                       t-stat   (0.9832)  (0.7121)  (0.8787)  (0.5612)
# Time FE                           False      True     False      True
# Entity FE                         False     False      True      True
# N                                  1675      1675      1675      1675
# R-squared                        0.0031    0.0026    0.0003    0.0002
# R-squared (inclusive)            0.0031    0.2416    0.1248    0.3488
#
#                                     (9)       (10)       (11)       (12)
# const                 coeff     -0.0102
#                       t-stat  (-1.0597)
# in                    coeff      1.0640     0.7858   1.5141**   1.1404**
#                       t-stat   (1.5122)   (1.3778)   (2.2280)   (2.1847)
# out                   coeff      0.2022    -0.7158     0.0293  -0.9690**
#                       t-stat   (0.2858)  (-1.3206)   (0.0416)  (-2.1822)
# capm_mktrf_est        coeff      0.0014     0.0052   -0.0122*    -0.0045
#                       t-stat   (0.0934)   (0.3160)  (-1.9018)  (-0.5047)
# Time FE                           False       True      False       True
# Entity FE                         False      False       True       True
# N                                  1675       1675       1675       1675
# R-squared                        0.0095     0.0038     0.0108     0.0027
# R-squared (inclusive)            0.0095     0.2424     0.1340     0.3505
