# %% [markdown]
# ## Imports

# %%
import wrds
import pandas as pd
import numpy as np
import datetime as dt
import sys

#import pandas_datareader.data as web

#import requests
#import io
#import zipfile

#import mypack.data as data

# %% [markdown]
# ## Set up WRDS Connection

# %%
wrds_conn = wrds.Connection(wrds_username='felixbru')
#wrds_connection.create_pgpass_file()
#wrds_connection.close()
# Out:
# Loading library list...
# Done

# %% [markdown]
# ## Select data

# %%
libraries = wrds_conn.list_libraries()
libraries.sort()
libraries[0:10]
# Out:
# ['aha',
#  'aha_sample',
#  'ahasamp',
#  'audit',
#  'bank',
#  'blab',
#  'block',
#  'boardex',
#  'boardex_trial',
#  'boardsmp']

# %%
library = 'crsp'#_a_stock'

# %%
library_tables = wrds_conn.list_tables(library=library)
library_tables.sort()
library_tables[0:10]
# Out:
# ['acti',
#  'asia',
#  'asib',
#  'asic',
#  'asio',
#  'asix',
#  'bmdebt',
#  'bmheader',
#  'bmpaymts',
#  'bmquotes']

# %%
table = 'dsf'

# %%
wrds_conn.describe_table(library=library, table=table).sort_values('name')
# Out:
# Approximately 96285900 rows in crsp.dsf.
#        name  nullable              type
# 13      ask      True  DOUBLE PRECISION
# 8     askhi      True  DOUBLE PRECISION
# 12      bid      True  DOUBLE PRECISION
# 7     bidlo      True  DOUBLE PRECISION
# 15   cfacpr      True  DOUBLE PRECISION
# 16  cfacshr      True  DOUBLE PRECISION
# 0     cusip      True           VARCHAR
# 6      date      True              DATE
# 4     hexcd      True  DOUBLE PRECISION
# 5    hsiccd      True  DOUBLE PRECISION
# 3    issuno      True  DOUBLE PRECISION
# 18   numtrd      True  DOUBLE PRECISION
# 17  openprc      True  DOUBLE PRECISION
# 2    permco      True  DOUBLE PRECISION
# 1    permno      True  DOUBLE PRECISION
# 9       prc      True  DOUBLE PRECISION
# 11      ret      True  DOUBLE PRECISION
# 19     retx      True  DOUBLE PRECISION
# 14   shrout      True  DOUBLE PRECISION
# 10      vol      True  DOUBLE PRECISION

# %% [markdown]
# ## Download CRSP data

# %%
columns = ['date', 'permno' ,'permco', 'ret', 'retx', 'prc', 'shrout', 'exchcd']

# %%
other_data = wrds_conn.raw_sql("""
                      select a.permno, a.permco, a.date, b.shrcd, b.exchcd,
                      a.ret, a.retx, a.shrout, a.prc
                      from crsp.msf as a
                      left join crsp.msenames as b
                      on a.permno=b.permno
                      and b.namedt<=a.date
                      and a.date<=b.nameendt
                      where a.date between '01/01/1959' and '12/31/2017'
                      and b.exchcd between 1 and 3
                      """)

# %%
other_data.head(20)#shape
# Out:
#      permno  permco        date  shrcd  exchcd       ret      retx  shrout  \
# 0   10000.0  7952.0  1986-01-31   10.0     3.0       NaN       NaN  3680.0
# 1   10001.0  7953.0  1987-11-30   11.0     3.0 -0.029412 -0.029412   992.0
# 2   10001.0  7953.0  1987-12-31   11.0     3.0 -0.033535 -0.050505   992.0
# 3   10001.0  7953.0  1988-01-29   11.0     3.0  0.063830  0.063830   992.0
# 4   10001.0  7953.0  1988-02-29   11.0     3.0  0.080000  0.080000   992.0
# 5   10001.0  7953.0  1988-03-31   11.0     3.0 -0.076296 -0.092593   992.0
# 6   10001.0  7953.0  1988-04-29   11.0     3.0  0.030612  0.030612   992.0
# 7   10001.0  7953.0  1988-05-31   11.0     3.0  0.019802  0.019802   992.0
# 8   10001.0  7953.0  1988-06-30   11.0     3.0 -0.012039 -0.029126   992.0
# 9   10001.0  7953.0  1988-07-29   11.0     3.0  0.030000  0.030000   992.0
# 10  10001.0  7953.0  1988-08-31   11.0     3.0  0.029126  0.029126   992.0
# ...

# %%
import sys
sys.getsizeof(other_data)
# Out:
# 399183040

# %%
crsp_data = wrds_conn.get_table(library=library, table=table, columns=columns)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     508     def do_execute(self, cursor, statement, parameters, context=None):
# --> 509         cursor.execute(statement, parameters)
#     510
#
# UndefinedColumn: column "exchcd" does not exist
# LINE 1: SELECT date,permno,permco,ret,retx,prc,shrout,exchcd FROM cr...
#                                                       ^
# HINT:  Perhaps you meant to reference the column "dsf.hexcd".
#
#
# ...

# %%
# download
crsp_data = wrds_conn.get_table(library='crspa', table='dsi', columns=['date','vwretd'])

# edit data formats
crsp_data['date'] = pd.to_datetime(crsp_data['date'], yearfirst=True)

# declare index
crsp_data.set_index('date', inplace=True)

# rename variables
crsp_data = crsp_data.rename(columns={'vwretd':'vw_index'})

# %%
#tbill = wrds_conn.get_table(library='crspa', table='TFZ_DLY', columns=['CALDT','TDNOMPRC'])

# %% [markdown]
# ## Download FF data

# %%
factors_daily = data.download_factor_data('D')/100
factors_monthly = data.download_factor_data('M')/100

# %% [markdown]
# ## Merge

# %%
df_merged = crsp_data.merge(factors_daily[['Mkt-RF','RF']], left_index=True, right_on='Date')#, how='outer')
df_merged['vw-RF'] = df_merged['vw_index'] - df_merged['RF']
